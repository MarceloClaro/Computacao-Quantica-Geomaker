# %% [markdown]
# <a href="https://colab.research.google.com/github/MarceloClaro/Computacao-Quantica-Geomaker/blob/main/AULA_2_No%C3%A7%C3%B5es_b%C3%A1sicas_de_informa%C3%A7%C3%A3o_qu%C3%A2ntica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![DALL·E 2023-11-18 07.50.51 - An icon design for the logo 'GEOQUANTICA', with the title 'GEOQUANTICA' prominently displayed. The design should be clean, round, and of high quality,.png](data:image/png;base64,...)

# %% [markdown]
# # **Ementa do Estudo: Aventura Quântica com Qiskit**
# ***PROF. MARCELO CLARO.***
#
# #### 1. **Introdução à Computação Quântica e ao Qiskit**
#    - Visão geral da computação quântica.
#    - Introdução ao Qiskit como ferramenta de programação quântica.
#
# #### 2. **Fundamentos de Python para Computação Quântica**
#    - Conceitos básicos de Python focados em vetores e matrizes.
#    - Uso do NumPy para cálculos matemáticos.
#
# #### 3. **Explorando a Classe Statevector**
#    - Criação e manipulação de estados quânticos com Statevector.
#    - Visualização e validação de estados quânticos.
#
# #### 4. **Medições e Probabilidades no Mundo Quântico**
#    - Simulação de medições quânticas.
#    - Entendimento dos resultados probabilísticos das medições.
#
# #### 5. **Introdução aos Circuitos Quânticos**
#    - Conceitos básicos de circuitos quânticos.
#    - Construção de um circuito quântico simples com QuantumCircuit.
#
# #### 6. **Operações e Transformações Quânticas**
#    - Aplicação de operações quânticas básicas.
#    - Entendimento do impacto das operações nos estados quânticos.
#
# #### 7. **Simulação de Experimentos Quânticos**
#    - Simulação completa de um experimento quântico.
#    - Análise de resultados com múltiplas medições.
#
# #### 8. **Visualização de Resultados com Histogramas**
#    - Uso de plot_histogram para visualizar os resultados das medições.
#
# #### Referências e Recursos Adicionais
# Para aprofundar-se nos conceitos abordados e explorar mais sobre o Qiskit e a computação quântica, confira as seguintes referências:
#
# 1. **Qiskit Official Website**: [Qiskit](https://qiskit.org/)
# 2. **Qiskit Documentation**: [Qiskit Docs](https://qiskit.org/documentation/)
# 3. **Python NumPy Tutorial**: [NumPy Official](https://numpy.org/doc/stable/user/quickstart.html)
# 4. **Introduction to Quantum Computing**: [Quantum Computing Introduction](https://www.ibm.com/quantum-computing/learn/what-is-quantum-computing/)
# 5. **Quantum Circuits Introduction**: [Quantum Circuits](https://quantum-computing.ibm.com/composer/docs/iqx/guide/quantum-circuits)
#
#
# ---
#
#
#
#
#
# > `Esta ementa oferece um panorama completo da nossa jornada de aprendizado, guiando você através de cada etapa fundamental no mundo fascinante da computação quântica com Qiskit.`
#
#
#
#
# ---

# %% [markdown]
# # **Prefácio: Embarcando na Aventura Quântica com Qiskit**
#
#
# ---
#
#
#
# Bem-vindos à emocionante jornada de descoberta no universo da computação quântica com Qiskit! Este prelúdio é uma porta de entrada para um mundo onde a ciência encontra a imaginação, onde os conceitos abstratos de física quântica e programação se transformam em aventuras palpáveis e compreensíveis.
#
# Através de uma série de explorações interativas e didáticas, esta jornada é desenhada não apenas para ensinar, mas para encantar. Cada passo é uma oportunidade de desvendar os mistérios da computação quântica, tornando-os acessíveis para mentes curiosas, independentemente de sua idade ou experiência prévia.
#
# Aqui, você não encontrará apenas lições, mas histórias. Histórias que tecem a matemática com a magia, os conceitos científicos com a criatividade. Esta jornada é mais do que um aprendizado; é uma experiência que busca inspirar e instigar a curiosidade.
#
# Ao embarcar nesta aventura com Qiskit, prepare-se para explorar o mundo dos qubits, estados quânticos, circuitos e simulações. Cada elemento é apresentado de forma que torna o aprendizado uma atividade divertida e envolvente, adequada para todas as idades.
#
# Este preâmbulo é um convite para você abrir sua mente, acender sua imaginação e mergulhar no maravilhoso mundo da computação quântica. Juntos, vamos desbravar este caminho, descobrindo não apenas o poder e o potencial da computação quântica, mas também a capacidade de transformar complexidade em clareza, incerteza em compreensão e desafios em conquistas.
#
# Então, respire fundo e prepare-se para uma viagem como nenhuma outra - uma viagem onde cada descoberta é um tesouro e cada conceito uma nova fronteira a ser explorada. Bem-vindo à aventura quântica com Qiskit! 🌠🔍✨🚀

# %% [markdown]
# ---
#
#
#
# > `Aqui está um sumário simplificado da nossa interação sobre o aprendizado do Qiskit, organizado em etapas chave:`
#
#
#
# ---
#
#
#
# ### **Sumário da Jornada de Aprendizado no Qiskit**
#
# #### 1. **Explorando o Qiskit**
#    - Introdução ao Qiskit como uma ferramenta para computação quântica.
#
# #### 2. **Vetores e Matrizes com Python**
#    - Uso de Python para entender vetores e matrizes, essenciais na computação quântica.
#
# #### 3. **Dominando a Classe Statevector**
#    - Aprendizado sobre a `Statevector` no Qiskit para criar e manipular estados quânticos.
#
# #### 4. **Desenhando e Validando Estados Quânticos**
#    - Uso de métodos para visualizar estados quânticos e verificar sua validade.
#
# #### 5. **Simulação de Medições Quânticas**
#    - Exploração de como simular medições e entender seus resultados probabilísticos.
#
# #### 6. **Experimentação com Resultados de Medições**
#    - Observação de como diferentes medições podem produzir diferentes resultados.
#
# #### 7. **Introdução aos Circuitos Quânticos**
#    - Primeiros passos no aprendizado de circuitos quânticos e sua importância.
#
# #### 8. **Construindo e Operando um Circuito Quântico**
#    - Criação de um circuito quântico e aplicação de operações quânticas básicas.
#
# #### 9. **Simulação de um Experimento Quântico Completo**
#    - Simulação do resultado de um circuito quântico e análise dos resultados com muitas medições.
#
# Este sumário reflete nossa jornada passo a passo pelo fascinante mundo da computação quântica com Qiskit, mantendo o aprendizado acessível e envolvente. 🌌🎓👨‍🔬🚀

# %% [markdown]
# ---
#
#
# # **Introdução**
#
#
# ---
#
#
#
#
# Imagine que estamos falando de um tipo especial de informação que é muito diferente daquela que usamos em nossos computadores e celulares. Essa informação é chamada de "informação quântica". É como um jogo de quebra-cabeça matemático muito legal, mas um pouco complicado.
#
# Primeiro, precisamos entender algumas coisas. Em vez de usar números comuns como 1, 2, 3, usamos números especiais chamados "números complexos". Eles são como números mágicos que podem ser escritos como a + bi, onde "a" e "b" são números regulares, mas "i" é um número especial que significa a raiz quadrada de -1. Isso pode parecer estranho, mas é assim que os matemáticos descrevem coisas no mundo quântico.
#
# Agora, imagine que temos algo chamado "estado quântico". É como uma descrição especial de algo que está acontecendo no mundo quântico. Podemos representar esse estado quântico usando setas especiais chamadas "vetores". Essas setas têm números complexos como suas coordenadas, o que significa que apontam em direções especiais no espaço.
#
# Agora, vamos falar sobre "medidas". Quando queremos saber algo sobre um estado quântico, fazemos uma medida. É como se estivéssemos jogando dardos em um alvo, e a medida nos diz onde o dardo acertou. Mas a coisa estranha é que, ao fazer a medida, o estado quântico muda! Isso é muito diferente do nosso mundo normal, onde medir algo não o muda.
#
# Por fim, temos "operações quânticas", que são como regras especiais para mexer com estados quânticos. Essas regras são representadas por matrizes chamadas "matrizes unitárias". Essas matrizes nos dizem como transformar um estado quântico em outro de uma maneira muito específica.
#
# Aqui está um exemplo simples: imagine que temos um gato mágico que pode estar em dois estados ao mesmo tempo, como acordado e dormindo. Se quisermos saber em que estado ele está, fazemos uma medida e ele se tornará apenas acordado ou apenas dormindo.
#
# Tudo isso é muito estranho, mas é assim que as coisas funcionam no mundo quântico. Existem ainda mais coisas legais para aprender sobre informação quântica, mas por enquanto, isso deve ser suficiente para você começar a entender como funciona. No futuro, você pode aprender sobre matrizes de densidade e outras coisas emocionantes!

# %% [markdown]
# ---
#
#
# # **Informação clássica**
#
#
# ---
#
#
# Pense na informação clássica como algo que você já usa todos os dias. É como quando você tem que escolher entre sabores de sorvete. Você pode escolher chocolate, baunilha ou morango. Essas são suas opções, e você escolhe uma delas.
#
# Agora, imagine que essas escolhas de sorvete são como informações clássicas. É simples e direto, certo? Você faz uma escolha, e essa escolha é a informação que você tem.
#
# Agora, a informação quântica é um pouco mais complicada. É como se você pudesse escolher não apenas um sabor de sorvete, mas vários ao mesmo tempo! Por exemplo, você poderia escolher chocolate e baunilha ao mesmo tempo, mas quando você mede, você acaba com apenas um sabor, digamos, chocolate.
#
# Então, a informação clássica é como fazer uma escolha única, enquanto a informação quântica permite que você tenha múltiplas escolhas ao mesmo tempo, mas você só vê uma delas quando mede.
#
# Agora, a razão pela qual aprendemos sobre a informação clássica em um curso sobre informação quântica é que a matemática usada para descrever essas duas coisas é parecida. É como se fossem dois quebra-cabeças diferentes, mas as peças se encaixam de maneira semelhante.
#
# Além disso, entender a informação clássica nos ajuda a entender melhor a informação quântica. Às vezes, podemos usar exemplos da informação clássica para explicar coisas na informação quântica de maneira mais fácil.
#
# Por exemplo, quando falamos sobre informações quânticas, podemos usar a notação de Dirac para descrever vetores e matrizes. Isso pode parecer complicado, mas a notação de Dirac é como um conjunto especial de regras que nos ajuda a representar coisas de maneira organizada. E adivinhe? Também podemos usá-la quando estamos falando de informações clássicas!
#
# Então, em resumo, a informação clássica é como escolher uma coisa de cada vez, como escolher um sabor de sorvete. E a informação quântica é como escolher várias coisas ao mesmo tempo, mas só ver uma delas quando medimos. E aprender sobre a informação clássica nos ajuda a entender a informação quântica melhor.

# %% [markdown]
# ## **Estados clássicos e vetores de probabilidade**
# Vou explicar o conceito de estados clássicos e vetores de probabilidade de uma forma que uma criança de 10 anos possa entender.
#
# Imagine que temos um sistema que guarda informações, como um brinquedo que pode estar em diferentes estados. Por exemplo, pense em um brinquedo que pode estar em dois estados: ligado ou desligado. Isso é o que chamamos de "estado clássico". É como se o brinquedo estivesse em uma posição específica que podemos ver e descrever facilmente.
#
# Agora, pense em outros brinquedos, como um dado de seis lados, um interruptor de ventilador ou até mesmo as letras do DNA. Cada um deles também tem diferentes estados clássicos que podemos reconhecer, como os números de um dado ou as letras do DNA. Isso é o que chamamos de "conjunto de estados clássicos".
#
# Então, se tivermos um brinquedo que pode estar em vários estados, podemos usar um vetor para representar as chances de estar em cada estado. Por exemplo, se tivermos um brinquedo que pode estar ligado ou desligado, podemos usar um vetor como este:
#
# - Ligado: 3/4 (75% de chance)
# - Desligado: 1/4 (25% de chance)
#
# Isso nos diz que há uma maior chance de o brinquedo estar ligado (75%) e uma menor chance de estar desligado (25%). Esses números somam 100%, o que é importante.
#
# Agora, podemos usar vetores assim para representar qualquer brinquedo ou sistema com estados clássicos. As regras são simples:
#
# 1. As entradas do vetor são números reais não negativos, o que significa que não podem ser números negativos.
# 2. A soma de todas as entradas do vetor é igual a 1, o que garante que representamos todas as possíveis chances.
#
# Então, quando pensamos em um brinquedo ou sistema, podemos usar vetores de probabilidade para mostrar quais estados são mais prováveis e quais são menos prováveis. É como fazer um jogo de adivinhação, onde tentamos descobrir qual estado o sistema está usando as probabilidades. E quando fazemos cálculos com esses vetores, usamos multiplicação de matrizes para saber como as chances mudam quando algo acontece.
#
# Espero que isso ajude a entender como funcionam os estados clássicos e os vetores de probabilidade!

# %%
pip install qiskit

# %% [markdown]
# ### **Exemplos de Qiskit**
#
#
# ---
#
#
# Nesta seção, apresentamos alguns exemplos de implementações do Qiskit dos conceitos introduzidos nesta lição.
#
# Vetores e matrizes em Python
#
# O Qiskit usa a linguagem de programação Python, portanto, antes de discutir o Qiskit especificamente, pode ser útil discutir muito brevemente os cálculos de matriz e vetor em Python. Em Python, cálculos matriciais e vetoriais podem ser realizados usando a classe array da biblioteca NumPy (que inclui muitos componentes adicionais para computação numérica).
#
# Aqui está um exemplo de uma célula de código que define dois vetores, ket0 e ket1 , correspondentes aos vetores de estado qubit ∣0⟩\vert 0\rangle∣0⟩ e ∣1⟩,\vert 1\rangle,∣1⟩, e exibe sua média.
#
#
# ---

# %%
from numpy import array

ket0 = array([1, 0])
ket1 = array([0, 1])

display(ket0 / 2 + ket1 / 2)

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# > `Ensinar Qiskit para uma criança de 10 anos pode ser um desafio interessante e divertido. Vou tentar explicar de forma simples e acessível. Imagine que estamos brincando com um tipo especial de matemática que envolve números e letras ao mesmo tempo, e isso nos ajuda a entender como os computadores do futuro (computadores quânticos) funcionam.`
#
#
#
# ---
#
#
# ## 🌟**Introdução ao Qiskit com Vetores e Matrizes**
#
#
# ---
#
#
#
# #### **O Mundo dos Vetores**
# Primeiro, pense em vetores como setas. Essas setas podem apontar para diferentes direções e têm tamanhos diferentes. No mundo dos computadores quânticos, temos vetores especiais chamados 'ket0' e 'ket1'. Eles são como setas que apontam para duas direções muito importantes.
#
# **Ket0** é como uma seta apontando para cima, e **Ket1** é como uma seta apontando para baixo. No mundo quântico, essas setas representam o que um qubit (um tipo muito especial de 'bit' usado em computadores quânticos) pode ser.
#
# #### **Usando Python para Brincar com Vetores**
# Para brincar com esses vetores, usamos uma linguagem chamada Python. É como aprender uma nova língua para falar com o computador. No Python, usamos algo chamado 'NumPy', que é uma caixa de ferramentas que nos ajuda a fazer contas com vetores e matrizes (matrizes são como tabelas cheias de números).
#
# #### **Um Exemplo Simples**
#
# Vamos ver um exemplo. Imagine que queremos saber qual é a média (o valor no meio) entre os vetores ket0 e ket1. No Python, escrevemos algo assim:
#
# ```python
# import numpy as np
#
# # ket0 é como uma seta apontando para cima
# ket0 = np.array([1, 0])
#
# # ket1 é como uma seta apontando para baixo
# ket1 = np.array([0, 1])
#
# # A média dos dois vetores
# media = (ket0 + ket1) / 2
#
# print("A média é:", media)
# ```
#
# Quando rodamos isso, o Python vai nos mostrar a média dos dois vetores, ou seja, o que fica no meio entre a seta para cima e a seta para baixo.
#
# #### **Por Que Isso é Importante?**
# Aprender sobre esses vetores e como calcular com eles é o primeiro passo para entender como os computadores quânticos funcionam. Eles usam essas ideias para fazer cálculos muito rápidos e resolver problemas que os computadores normais acham muito difíceis.
#
# Então, brincar com o Qiskit e Python é como ser um explorador em um mundo novo e emocionante, onde aprendemos a falar a língua dos computadores quânticos! É como uma grande aventura matemática. 😊🚀🌌

# %%
import numpy as np

# ket0 é como uma seta apontando para cima
ket0 = np.array([1, 0])

# ket1 é como uma seta apontando para baixo
ket1 = np.array([0, 1])

# A média dos dois vetores
media = (ket0 / 2 + ket1 / 2)

print("A média é:", media)

# %% [markdown]
# ---
#
#
# Na verdade, não é necessário usar explicitamente o comando display para ver o resultado dessa computação. Em vez disso, podemos simplesmente escrever a expressão de interesse como a última linha da célula de código, e ela será retornada como sua saída:

# %%
ket0 / 2 + ket1 / 2

# %% [markdown]
# ![Untitled (1).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# > `Claro! Vamos continuar nossa aventura no mundo do Qiskit e do Python, explicando de uma maneira bem simples e divertida, como se estivéssemos em uma história.`
#
# ---
#
#
#
#
# ## 🌈 **Simplificando a Matemática no Python**
#
#
# ---
#
#
#
# Imagine que você está escrevendo um bilhete mágico para um amigo imaginário, o Python. Nesse bilhete, você pede para ele calcular algo para você. No nosso caso, queremos saber a média dos vetores "ket0" e "ket1", que são como duas setas mágicas.
#
# #### **A Mágica de Pedir ao Python**
# No mundo do Python, há um truque especial: se você escrever algo que quer saber na última linha de seu bilhete, o Python automaticamente lhe mostra a resposta! Então, não precisamos pedir explicitamente com o comando "display". É como se o Python adivinhasse o que queremos saber.
#
# #### **O Truque com Ket0 e Ket1**
# Lembra do ket0 (a seta para cima) e do ket1 (a seta para baixo)? Agora, vamos pedir ao Python para nos mostrar o que fica no meio deles, sem precisar dizer "por favor, mostre-me isso". Basta escrever a conta na última linha do bilhete. Veja como é fácil:
#
# ```python
# import numpy as np
#
# # ket0 é a seta para cima
# ket0 = np.array([1, 0])
#
# # ket1 é a seta para baixo
# ket1 = np.array([0, 1])
#
# # Perguntamos ao Python: Qual é a média?
# ket0 / 2 + ket1 / 2
# ```
#
# Quando você fizer isso, o Python, como um amigo mágico, vai lhe mostrar a média, a resposta para sua pergunta, sem que você precise usar palavras especiais. É como se ele lesse seus pensamentos!
#
# #### **Por que Isso é Mágico?**
# Essa maneira de falar com o Python nos ajuda a ser rápidos e eficientes. É como aprender um atalho em um jogo ou descobrir um segredo que faz as coisas funcionarem mais rápido e de maneira mais divertida.
#
# Assim, aprender Qiskit com Python é como ter um amigo mágico que nos ajuda a entender o mundo incrível e misterioso dos computadores quânticos, onde as coisas funcionam de maneira diferente, mas muito interessante. E o melhor de tudo, é que estamos aprendendo brincando! 🌟💻🎈

# %% [markdown]
# ---
#
#
# Essa célula de código também ilustra que a execução de células de código sequencialmente em uma determinada página deste livro didático tem um efeito cumulativo, portanto, não é necessário recarregar a classe de matriz ou definir ket0 e ket1 novamente. Recarregar a página ou mudar para outra página irá, no entanto, redefinir tudo para seu estado inicial.
#
# Como diretriz geral, as células de código dentro de cada subseção deste curso devem ser executadas sequencialmente. Portanto, se a execução de uma célula de código gerar um erro, certifique-se de executar primeiro todas as células de código anteriores dentro da subseção na qual essa célula de código aparece.
#
# Também podemos usar array para criar matrizes que representam operações.

# %%
M1 = array([[1, 1], [0, 0]])
M2 = array([[1, 1], [1, 0]])

M1 / 2 + M2 / 2

# %% [markdown]
# ![Untitled (2).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# > `Vamos continuar nossa aventura de aprendizagem com Qiskit e Python de uma forma fácil e divertida. Imagine que estamos em um jogo de vídeo game onde cada célula de código é uma fase do jogo.`
#
# ---
#
# ## 🎮 **Células de Código como Fases de um Jogo**
#
# #### **As Fases se Conectam**
# No nosso jogo, cada fase (célula de código) que você completa afeta a próxima. Então, se você já escreveu algo em uma fase, não precisa escrever tudo de novo na próxima. É como se cada fase lembrasse do que você fez antes.
#
# #### **Salvando o Progresso**
# Assim como em muitos jogos, se você sair da página ou mudar de fase (página), o jogo volta para o começo. No nosso caso, se você fechar ou mudar a página do seu código, vai precisar começar de novo, escrevendo o ket0 e o ket1 outra vez.
#
# #### **Jogando na Ordem Certa**
# É importante jogar as fases na ordem certa. Se você tentar pular para uma fase sem ter completado as anteriores, pode ser que o jogo não funcione. No Python, isso significa que você deve executar as células de código em ordem para que tudo funcione bem.
#
# ### 🧩 **Criando Matrizes Mágicas**
#
# Agora, vamos aprender a criar matrizes mágicas, que são como tabelas cheias de números.
#
# #### **Exemplo de Matrizes**
# Imagine que temos duas matrizes mágicas, M1 e M2. Elas são como caixas cheias de tesouros (números) e cada tesouro tem sua própria posição na caixa.
#
# Vamos criar M1 e M2:
#
# ```python
# import numpy as np
#
# # M1 é uma caixa com tesouros [1, 1] na parte de cima e [0, 0] na parte de baixo
# M1 = np.array([[1, 1], [0, 0]])
#
# # M2 é outra caixa com tesouros [1, 1] na parte de cima e [1, 0] na parte de baixo
# M2 = np.array([[1, 1], [1, 0]])
#
# # Vamos ver o que tem no meio das duas caixas
# M1 / 2 + M2 / 2
# ```
#
# Quando rodamos isso, o Python, como um mágico, mostra o que tem no meio das duas matrizes mágicas.
#
# #### **Por que Isso é Divertido?**
# Com Qiskit e Python, estamos aprendendo a jogar um jogo muito especial onde as fases são células de código e as matrizes são caixas de tesouros. Cada passo que damos nos ajuda a entender mais sobre o mundo incrível dos computadores quânticos e como eles vão mudar o futuro!
#
# E o mais legal é que estamos aprendendo tudo isso brincando, como se estivéssemos em uma aventura mágica! 🌌🎲🚀

# %%
import numpy as np

# M1 é uma caixa com tesouros [1, 1] na parte de cima e [0, 0] na parte de baixo
M1 = np.array([[1, 1], [0, 0]])

# M2 é outra caixa com tesouros [1, 1] na parte de cima e [1, 0] na parte de baixo
M2 = np.array([[1, 1], [1, 0]])

# Vamos ver o que tem no meio das duas caixas
M1 / 2 + M2 / 2

# %% [markdown]
# ---
#
#
# A multiplicação de matrizes (incluindo a multiplicação matriz-vetor como um caso especial) pode ser realizada usando a função matmul do NumPy :

# %%
from numpy import matmul

display(matmul(M1, ket1))
display(matmul(M1, M2))
display(matmul(M2, M1))

# %% [markdown]
# ![Untitled (3).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# > `Vamos continuar nossa aventura pelo mundo do Qiskit e Python! Hoje, vamos aprender sobre um tipo de mágica muito especial: a multiplicação de matrizes. É como um quebra-cabeça onde combinamos diferentes peças para criar algo novo.`
#
#
# ---
#
#
#
#
#
#
# ### 🧙‍♂️ **Multiplicação de Matrizes: Um Quebra-Cabeça Mágico**
#
# #### Entendendo Matrizes e Vetores
# Primeiro, lembra das nossas caixas de tesouros, as matrizes M1 e M2? E das setas mágicas, os vetores ket0 e ket1? Agora, vamos brincar de combinar essas caixas e setas para ver o que acontece.
#
# #### **Usando uma Varinha Mágica Chamada 'matmul'**
# No Python, temos uma varinha mágica chamada `matmul` que nos ajuda a combinar matrizes e vetores. É como se estivéssemos juntando peças de um quebra-cabeça para ver uma figura nova.
#
# #### **Vamos Experimentar!**
# Aqui estão alguns exemplos de como usar a varinha mágica `matmul`:
#
# ```python
# from numpy import matmul, array
#
# # Nossas caixas de tesouros (matrizes) e setas mágicas (vetores)
# M1 = array([[1, 1], [0, 0]])
# M2 = array([[1, 1], [1, 0]])
# ket1 = array([0, 1])
#
# # Combinando a caixa M1 e a seta ket1
# resultado1 = matmul(M1, ket1)
# print("Resultado de M1 e ket1:", resultado1)
#
# # Combinando as caixas M1 e M2
# resultado2 = matmul(M1, M2)
# print("Resultado de M1 e M2:", resultado2)
#
# # Combinando as caixas M2 e M1
# resultado3 = matmul(M2, M1)
# print("Resultado de M2 e M1:", resultado3)
# ```
#
# Quando rodamos esses comandos, o Python mostra os resultados das combinações. Cada combinação é como uma nova descoberta em nosso quebra-cabeça mágico.
#
# #### **Por que Isso é Incrível?**
# Ao aprender sobre multiplicação de matrizes, estamos descobrindo como combinar diferentes peças de informação de maneiras novas e emocionantes. É como se estivéssemos aprendendo a linguagem secreta dos computadores quânticos!
#
# E o mais divertido é que, a cada passo, estamos nos tornando pequenos mágicos no mundo da matemática e da programação. Continuando assim, logo poderemos fazer muitas outras mágicas incríveis com o Qiskit e o Python! 🌠✨💻

# %%
from numpy import matmul, array

# Nossas caixas de tesouros (matrizes) e setas mágicas (vetores)
M1 = array([[1, 1], [0, 0]])
M2 = array([[1, 1], [1, 0]])
ket1 = array([0, 1])

# Combinando a caixa M1 e a seta ket1
resultado1 = matmul(M1, ket1)
print("Resultado de M1 e ket1:", resultado1)

# Combinando as caixas M1 e M2
resultado2 = matmul(M1, M2)
print("Resultado de M1 e M2:", resultado2)

# Combinando as caixas M2 e M1
resultado3 = matmul(M2, M1)
print("Resultado de M2 e M1:", resultado3)

# %% [markdown]
# ---
#
#
# Estados, medições e operações
# O Qiskit inclui várias classes que permitem que estados, medições e operações sejam facilmente criados e manipulados — portanto, começar do zero e programar tudo o que é necessário para simular estados quânticos, medições e operações em Python não é necessário. Alguns exemplos para começar estão incluídos abaixo.
#
# Definindo e exibindo vetores de estado
# A classe Statevector do Qiskit fornece funcionalidade para definir e manipular vetores de estado quântico. A célula de código a seguir importa a classe Statevector e define alguns vetores usando-a. (Observe que precisamos da função sqrt da biblioteca NumPy para calcular as raízes quadradas para o vetor u .)

# %%
from qiskit.quantum_info import Statevector
from numpy import sqrt

u = Statevector([1 / sqrt(2), 1 / sqrt(2)])
v = Statevector([(1 + 2.0j) / 3, -2 / 3])
w = Statevector([1 / 3, 2 / 3])

print("Os vetores de estado u, v e w foram definidos.")

# %% [markdown]
# ![Untitled (4).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
#
# > `Vamos aprender sobre estados, medições e operações no Qiskit de uma maneira bem simples e divertida! É como se estivéssemos descobrindo um baú do tesouro cheio de ferramentas mágicas.`
#
#
#
#
# ---
#
#
#
# ## 🌌 **Estados Quânticos: O Começo da Magia**
#
# #### O que é um Estado Quântico?
# No mundo dos computadores quânticos, um "estado quântico" é como um personagem em um jogo de vídeo game. Esse personagem pode estar em diferentes posições (estados), e essas posições nos dizem algo sobre ele. No Qiskit, aprendemos a controlar e entender esses personagens mágicos.
#
# #### **Usando a Classe Statevector**
# No Qiskit, temos uma ferramenta chamada `Statevector`. É como uma varinha mágica que nos ajuda a criar e mudar os estados quânticos (os personagens).
#
# ### 🧙‍♂️ **Criando Nossos Personagens Mágicos**
#
# Vamos ver como criar alguns personagens usando a `Statevector`:
#
# 1. **Importando Ferramentas Mágicas**: Primeiro, precisamos das ferramentas certas. Vamos pegar a `Statevector` do Qiskit e a função `sqrt` do NumPy (que é como uma calculadora mágica para fazer contas especiais).
#
#    ```python
#    from qiskit.quantum_info import Statevector
#    from numpy import sqrt
#    ```
#
# 2. **Criando Personagens Especiais**: Agora, vamos criar três personagens especiais usando a nossa varinha mágica `Statevector`:
#
#    - **u**: Ele é meio e meio, metade aqui e metade lá. Usamos `1 / sqrt(2)` para dizer que ele está igualmente em dois lugares ao mesmo tempo.
#    - **v**: Este é um personagem misterioso com números especiais, chamados números complexos (como um número misturado com uma pitada de mágica).
#    - **w**: Este personagem gosta de números mais simples, como `1/3` e `2/3`.
#
#    Aqui está como criá-los:
#
#    ```python
#    u = Statevector([1 / sqrt(2), 1 / sqrt(2)])
#    v = Statevector([(1 + 2.0j) / 3, -2 / 3])
#    w = Statevector([1 / 3, 2 / 3])
#
#    print("Os vetores de estado u, v e w foram definidos.")
#    ```
#
#    Quando rodamos isso, o Python nos diz que os personagens u, v e w estão prontos para a aventura!
#
# #### **Por que Isso é Legal?**
# Aprender sobre `Statevector` e estados quânticos no Qiskit é como ter superpoderes para controlar um mundo novo e emocionante. Com esses personagens, podemos fazer experiências, resolver quebra-cabeças e descobrir segredos sobre como o universo funciona!
#
# E o mais legal é que estamos aprendendo tudo isso brincando, como se fôssemos magos em uma terra cheia de mistérios e aventuras! 🌟✨🔮

# %%
from qiskit.quantum_info import Statevector
from numpy import sqrt

# %%
u = Statevector([1 / sqrt(2), 1 / sqrt(2)])
v = Statevector([(1 + 2.0j) / 3, -2 / 3])
w = Statevector([1 / 3, 2 / 3])

print("Os vetores de estado u, v e w foram definidos.")

# %% [markdown]
# ---
#
#
# A classe Statevector fornece um método de desenho para exibir vetores de estado, incluindo opções de látex e texto para visualizações diferentes, como esta célula de código demonstra:

# %%
display(u.draw("latex"))
display(v.draw("text"))

# %% [markdown]
# ![Untitled (5).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
#
# > `Vamos mergulhar mais fundo no mundo mágico do Qiskit, aprendendo sobre como exibir nossos personagens (os estados quânticos) de uma maneira bem legal e visual!`
#
#
#
#
# ---
#
#
#
# ## 🎨 **Desenhando com a Classe Statevector**
#
# #### Uma Ferramenta para Desenhar Estados Quânticos
# A classe `Statevector` tem uma super habilidade: ela pode desenhar os estados quânticos para nós! É como se ela transformasse nossos personagens em figuras que podemos ver e entender melhor.
#
# #### **Diferentes Maneiras de Desenhar**
# Existem duas maneiras especiais de desenhar nossos estados quânticos:
#
# 1. **Desenho em Latex**: Esta forma é como uma pintura elegante. Ela usa um estilo chamado "latex" que é muito bonito e matemático.
# 2. **Desenho em Texto**: Esta é uma maneira mais simples, usando apenas texto. É como se desenhássemos com letras e números.
#
# ### 🖌️ **Experimentando com u e v**
#
# Vamos ver como desenhar nossos amigos u e v:
#
# 1. **Desenhando u em Latex**:
#    ```python
#    display(u.draw("latex"))
#    ```
#    Quando usamos isso, o Python nos mostra o estado quântico u como uma bela imagem matemática.
#
# 2. **Desenhando v em Texto**:
#    ```python
#    display(v.draw("text"))
#    ```
#    Com esse comando, o Python desenha o estado v em um estilo mais simples, usando apenas texto.
#
# #### **O que Aprendemos com Isso?**
# Ao desenhar os estados quânticos, estamos aprendendo a ver o mundo quântico de maneiras diferentes. Cada estilo de desenho nos ajuda a entender melhor como esses personagens especiais (os estados quânticos) se comportam e interagem.
#
# E o mais divertido é que estamos explorando a arte e a ciência ao mesmo tempo, descobrindo como expressar ideias complexas de maneira criativa e visual. É como se estivéssemos pintando um quadro do futuro, onde a matemática e a programação se encontram para criar algo belo e poderoso! 🎨💫🌌

# %%
display(u.draw("latex"))

# %%
display(v.draw("text"))

# %% [markdown]
# ---
#
#
# A classe Statevector também inclui o método is_valid , que verifica se um dado vetor é um vetor de estado quântico válido (ou seja, que tem norma euclidiana igual a 1):

# %%
display(u.is_valid())
display(w.is_valid())

# %% [markdown]
# ![Untitled (6).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# Vamos aprender mais uma coisa interessante sobre os estados quânticos e a classe `Statevector` no Qiskit! Dessa vez, vamos falar sobre como saber se um estado quântico é como um super-herói que segue as regras do seu mundo mágico.
#
#
# ---
#
#
#
# ## 🌟 **Verificando se um Estado Quântico é um Super-Herói**
#
# #### O Método is_valid: Como um Detector de Super-Heróis
# No mundo quântico, os estados quânticos (nossos personagens) precisam seguir uma regra muito importante: eles precisam ter uma coisa chamada "norma euclidiana igual a 1". Parece complicado, né? Mas é como se estivéssemos verificando se o super-herói tem o tamanho e a força certos para suas aventuras.
#
# A classe `Statevector` tem um método chamado `is_valid` que é como um detector de super-heróis. Ele nos diz se o nosso estado quântico está seguindo a regra importante.
#
# #### **Experimentando com u e v**
#
# Lembra do u e do v que criamos? Vamos ver se eles são super-heróis válidos:
#
# 1. **Verificando u**:
#    ```python
#    print(u.is_valid())
#    ```
#    Quando usamos isso, se o Python nos mostrar `True`, significa que o u é um super-herói válido!
#
# 2. **Verificando v**:
#    ```python
#    print(v.is_valid())
#    ```
#    Se o Python mostrar `False` para o v, significa que ele não está seguindo a regra. Ele é como um personagem que precisa de um pouco mais de treinamento para se tornar um super-herói válido.
#
# #### **Por que Isso é Importante?**
# Saber se um estado quântico é válido é como garantir que nossos super-heróis estão prontos para suas missões. No mundo da computação quântica, é essencial que os estados quânticos sigam as regras para que possam fazer coisas incríveis, como resolver problemas complicados muito rápido!
#
# E o mais legal é que estamos aprendendo a ser como detetives científicos, investigando e descobrindo os segredos do universo quântico! 🕵️‍♂️✨🚀

# %%
print(u.is_valid())

# %%
print(v.is_valid())

# %% [markdown]
# ---
#
#
# Simulando medições usando Statevector
# Em seguida, veremos uma maneira pela qual as medições de estados quânticos podem ser simuladas no Qiskit, usando o método de medida da classe Statevector .
#
# Primeiro, criamos um vetor de estado qubit v e, em seguida, o exibimos.

# %%
v = Statevector([(1 + 2.0j) / 3, -2 / 3])
v.draw("latex")

# %% [markdown]
# ![Untitled (7).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# > `Vamos aprender sobre como simular medições de estados quânticos usando o Qiskit, de uma maneira bem fácil e divertida, como se estivéssemos jogando um jogo de detetive!`
#
#
#
# ---
#
#
#
# ## 🕵️‍♂️ **Simulando Medições com Statevector**
#
# #### O que é uma Medição Quântica?
# No mundo quântico, fazer uma medição é como descobrir um segredo sobre um personagem (estado quântico). Quando medimos, estamos tentando descobrir onde esse personagem está ou o que ele está fazendo.
#
# #### **Usando o Statevector para Simular Medições**
# No Qiskit, podemos fingir que estamos fazendo essas medições com algo chamado `Statevector`. É como se estivéssemos usando uma lupa mágica para olhar mais de perto nossos personagens.
#
# ### 🌟** Criando e Observando um Novo Personagem: v**
#
# Vamos criar um novo personagem chamado v e usar nossa lupa mágica para olhá-lo:
#
# 1. **Criando o Personagem v**:
#    Primeiro, criamos o v, que é um pouco diferente. Ele tem números especiais chamados números complexos (um tipo de número que é meio mágico).
#
#    ```python
#    from qiskit.quantum_info import Statevector
#
#    # Criando o personagem v
#    v = Statevector([(1 + 2.0j) / 3, -2 / 3])
#    ```
#
# 2. **Observando v**:
#    Agora, vamos usar a nossa lupa mágica para ver como o v se parece.
#
#    ```python
#    v.draw("latex")
#    ```
#    Isso vai mostrar o v como uma imagem bonita e matemática.
#
# ### 🎩 **A Mágica da Medição**
#
# Agora, vamos fingir que estamos medindo o v para descobrir seus segredos:
#
# 1. **Medindo o v**:
#    Usamos um truque especial do `Statevector` para simular a medição.
#
#    ```python
#    resultado_medicao = v.measure()
#    print("Resultado da medição:", resultado_medicao)
#    ```
#
#    Isso nos diz o resultado da nossa "medição". É como se descobríssemos um segredo sobre o v!
#
# #### **Por que Isso é Divertido?**
# Simular medições no Qiskit é como jogar um jogo de detetive, onde tentamos descobrir os segredos dos personagens quânticos. Cada medição é como resolver um pedacinho de um mistério maior.
#
# E o mais incrível é que estamos aprendendo sobre o mundo quântico de uma maneira super divertida, como se estivéssemos em uma aventura cheia de magia e descobertas! 🌟🔍✨

# %%
from qiskit.quantum_info import Statevector

# Criando o personagem v
v = Statevector([(1 + 2.0j) / 3, -2 / 3])

# %%
v.draw("latex")

# %%
resultado_medicao = v.measure()
print("Resultado da medição:", resultado_medicao)

# %% [markdown]
# ---
#
#
# As células de código podem ser modificadas — então vá em frente e altere a especificação do vetor, se desejar.
#
# Em seguida, a execução do método de medida simula uma medição de base padrão. Ele retorna o resultado dessa medição, mais o novo estado quântico do nosso sistema após essa medição.

# %%
v.measure()

# %% [markdown]
# ![Untitled (8).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# > `Vamos continuar nossa aventura aprendendo como simular medições de estados quânticos no Qiskit, de um jeito bem fácil de entender. Imagine que estamos fazendo uma experiência científica para descobrir mais sobre o nosso personagem mágico, o estado quântico.`
#
#
#
# ---
#
#
#
# ## 🚀 **Experimentando com o Estado Quântico**
#
# #### **Modificando Células de Código**
# Primeiro, lembre-se de que podemos mudar as coisas nas células de código, como se estivéssemos ajustando nossa receita mágica. Isso significa que você pode mudar como o personagem (estado quântico) é feito. Por exemplo, você pode mudar os números que usamos para criar o v.
#
# #### **Simulando uma Medição com v.measure()**
# Depois de criar o nosso personagem v, vamos usar um truque especial chamado `v.measure()`. É como se estivéssemos usando um superpoder para ver o que acontece com o v quando fazemos uma medição.
#
# ### 🌌 **O Que Acontece Quando Medimos?**
#
# 1. **Usando v.measure()**:
#    Quando usamos `v.measure()`, estamos fazendo duas coisas:
#    - **Descobrindo um Segredo**: Ele nos conta um segredo sobre o v, como ele é ou onde ele está no mundo quântico.
#    - **Mudando o Personagem**: Ele também muda o v de alguma forma, como se ele se transformasse depois de descobrirmos o segredo.
#
#    Vamos experimentar:
#
#    ```python
#    resultado_medicao = v.measure()
#    print("Resultado da medição:", resultado_medicao)
#    ```
#
#    Aqui, o `resultado_medicao` é como uma mensagem especial que nos diz o segredo do v.
#
# #### 🧩 **O Que Aprendemos?**
#
# Cada vez que fazemos uma medição no mundo quântico, é como abrir uma caixa surpresa. Nunca sabemos exatamente o que vamos encontrar, mas sempre é algo interessante e novo. E depois de abrir a caixa, as coisas mudam um pouco, como se o universo estivesse nos contando uma história.
#
# Essa maneira de explorar e aprender sobre o Qiskit é como estar em uma aventura científica, onde cada experiência nos leva a descobertas incríveis e mágicas sobre como o mundo funciona! 🎩✨🌠

# %%
resultado_medicao = v.measure()
print("Resultado da medição:", resultado_medicao)

# %% [markdown]
# ---
#
#
# Os resultados das medidas são probabilísticos, de modo que o mesmo método pode retornar resultados diferentes. Tente executar a célula algumas vezes para ver isso.
#
# Para o exemplo particular do vetor v definido acima, o método de medida define o vetor de estado quântico após a medição ser
#
# 1+2i5∣0⟩\frac{1 + 2i}{\sqrt{5}} \vert 0\rangle
# 5
# ​
#
# 1+2i
# ​
#  ∣0⟩
# (em vez de ∣0⟩\vert 0\rangle∣0⟩) ou
#
# −∣1⟩- \vert 1\rangle
# −∣1⟩
# (em vez de ∣1⟩\vert 1\rangle∣1⟩), dependendo do resultado da medida. Em ambos os casos, as alternativas são, de fato, equivalentes – diz-se que diferem por uma fase global porque uma é igual à outra multiplicada por um número complexo no círculo unitário. Essa questão é discutida com mais detalhes na Lição 3 e pode ser ignorada com segurança por enquanto.
#
# Como um aparte, Statevector lançará um erro se o método de medida for aplicado a um vetor de estado quântico inválido. Sinta-se à vontade para experimentá-lo se estiver interessado em ver a aparência de um erro.
#
# Statevector também vem com um método sample_counts que permite a simulação de qualquer número de medições no sistema. Por exemplo, a célula a seguir mostra o resultado da medição do vetor v 1000 10001000 vezes, o que (com alta probabilidade) resulta no resultado 0 00 aproximadamente 5 55 de todos 9 99 vezes (ou cerca de 556 556556 do 1000 10001000 ensaios) e o resultado 1 11 aproximadamente 4 44 de todos 9 99 vezes (ou cerca de 444 444444 fora do 1000 10001000 ensaios). A célula também demonstra a função plot_histogram para visualizar os resultados.

# %%
from qiskit.visualization import plot_histogram

statistics = v.sample_counts(1000)
display(statistics)
plot_histogram(statistics)

# %% [markdown]
# ![Untitled (9).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# > `Vamos explorar como as medições no mundo quântico funcionam com o Qiskit, de uma maneira bem fácil e divertida! Imagine que estamos jogando um jogo onde tentamos adivinhar o que vai acontecer, mas com uma pitada de magia quântica.`
#
#
#
# ---
#
#
#
# ## 🌈 **Medições Quânticas: Um Jogo de Adivinhação**
#
# #### Resultados Surpresa
# No mundo quântico, quando fazemos uma medição, é como girar uma roda da fortuna. Às vezes, ela para em um lugar, às vezes em outro. Isso significa que, mesmo se fizermos a mesma coisa várias vezes, podemos obter resultados diferentes!
#
# #### **Experimentando com o v**
# Lembra do nosso amigo v? Quando medimos ele, às vezes ele nos mostra uma coisa, às vezes outra. Isso é porque os resultados são probabilísticos, ou seja, são baseados na chance, como um jogo de adivinhação.
#
# ### 🎲 **Jogando o Jogo das Medidas**
#
# 1. **Tentando Várias Vezes**:
#    Se tentarmos medir o v várias vezes, vamos ver que os resultados mudam. É como se cada vez que medimos, o v escolhesse se mostrar de uma maneira ou de outra.
#
# 2. **O que Acontece Depois da Medição**:
#    Dependendo do resultado, o v pode se transformar em uma versão diferente de si mesmo. É como se ele se disfarçasse depois que descobrimos seu segredo!
#
# #### **A Fase Global**
# Aqui temos algo chamado "fase global", que é um detalhe técnico sobre como os estados quânticos podem parecer diferentes, mas na verdade são a mesma coisa. É um pouco como se o v se vestisse de maneiras diferentes, mas ainda fosse o mesmo por dentro.
#
# ### 📊 **Simulando Muitas Medições com sample_counts**
#
# Agora, vamos ver o que acontece se fingirmos medir o v muitas vezes, como 1000 vezes!
#
# 1. **Usando sample_counts**:
#    Com `sample_counts`, podemos simular muitas medições de uma vez. É como se estivéssemos jogando o jogo da roda da fortuna 1000 vezes seguidas.
#
#    ```python
#    from qiskit.visualization import plot_histogram
#
#    # Fingindo medir o v 1000 vezes
#    statistics = v.sample_counts(1000)
#    ```
#
# 2. **Visualizando os Resultados com um Histograma**:
#    Depois, podemos usar um histograma para ver quantas vezes cada resultado aconteceu. É como um gráfico que nos mostra qual resultado foi mais comum.
#
#    ```python
#    plot_histogram(statistics)
#    ```
#
#    Isso nos mostra um belo gráfico com os resultados das nossas 1000 medições!
#
# #### **Por que Isso é Legal?**
# Fazer essas simulações nos ajuda a entender como os resultados quânticos são baseados em probabilidades. É como aprender a esperar o inesperado e ver a beleza e a surpresa na ciência!
#
# E o mais legal é que estamos fazendo tudo isso brincando, como se estivéssemos em uma aventura cheia de mistérios e descobertas incríveis! 🎩✨🔬

# %%
from qiskit.visualization import plot_histogram

# Fingindo medir o v 1000 vezes
statistics = v.sample_counts(1000)

# %%
plot_histogram(statistics)

# %% [markdown]
# ---
#
#
# Executando a célula várias vezes e tentando números diferentes de amostras no lugar de 1000 10001000 pode ser útil para desenvolver alguma intuição de como o número de tentativas influencia as probabilidades estimadas.
#
# Executando operações com Operador e Statevector
# As operações unitárias podem ser definidas e executadas em vetores de estado no Qiskit usando a classe Operator , como no exemplo a seguir.

# %%
from qiskit.quantum_info import Operator

X = Operator([[0, 1], [1, 0]])
Y = Operator([[0, -1.0j], [1.0j, 0]])
Z = Operator([[1, 0], [0, -1]])
H = Operator([[1 / sqrt(2), 1 / sqrt(2)], [1 / sqrt(2), -1 / sqrt(2)]])
S = Operator([[1, 0], [0, 1.0j]])
T = Operator([[1, 0], [0, (1 + 1.0j) / sqrt(2)]])

v = Statevector([1, 0])

v = v.evolve(H)
v = v.evolve(T)
v = v.evolve(H)
v = v.evolve(T)
v = v.evolve(Z)

v.draw("text")

# %%
v.draw("latex")

# %% [markdown]
# ![Untitled (12).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# > `Vamos aprender mais sobre como operações quânticas funcionam no Qiskit de um jeito bem divertido e fácil! Pense que estamos usando superpoderes para mudar nossos personagens quânticos.`
#
#
#
# ---
#
#
#
# ## 🚀 **Usando Superpoderes no Qiskit: Operações com Operador e Statevector**
#
# #### **O Que São Operações Unitárias?**
# Em computação quântica, operações unitárias são como feitiços mágicos que mudam os estados quânticos (nossos personagens). No Qiskit, usamos algo chamado `Operator` para criar esses feitiços.
#
# #### **Criando Feitiços Mágicos**
# Vamos ver alguns exemplos de feitiços mágicos (ou operações) que podemos usar:
#
# 1. **X, Y, Z, H, S, T**: Cada um desses é um tipo diferente de feitiço. Eles mudam os personagens de maneiras diferentes. Por exemplo, X é como um espelho que inverte as coisas, e H mistura as coisas.
#
#    Aqui está como os criamos:
#
#    ```python
#    from qiskit.quantum_info import Operator, Statevector
#    from numpy import sqrt
#
#    X = Operator([[0, 1], [1, 0]])
#    Y = Operator([[0, -1.0j], [1.0j, 0]])
#    Z = Operator([[1, 0], [0, -1]])
#    H = Operator([[1 / sqrt(2), 1 / sqrt(2)], [1 / sqrt(2), -1 / sqrt(2)]])
#    S = Operator([[1, 0], [0, 1.0j]])
#    T = Operator([[1, 0], [0, (1 + 1.0j) / sqrt(2)]])
#    ```
#
# #### **Transformando o Personagem v**
#
# 1. **Criando o v**:
#    Primeiro, criamos o personagem v como um vetor de estado simples.
#
#    ```python
#    v = Statevector([1, 0])
#    ```
#
# 2. **Aplicando os Feitiços**:
#    Agora, vamos usar nossos feitiços para transformar o v. Cada vez que usamos `v.evolve(NomeDoFeitiço)`, estamos aplicando um feitiço no v.
#
#    ```python
#    v = v.evolve(H)
#    v = v.evolve(T)
#    v = v.evolve(H)
#    v = v.evolve(T)
#    v = v.evolve(Z)
#    ```
#
#    Isso é como se estivéssemos contando uma história onde o v passa por várias aventuras e muda a cada passo.
#
# #### **Observando as Mudanças**
#
# 1. **Desenhando o v**:
#    Podemos usar `v.draw("text")` e `v.draw("latex")` para ver como o v ficou depois de todas essas aventuras.
#
#    ```python
#    v.draw("text")
#    v.draw("latex")
#    ```
#
#    Isso vai mostrar como o v mudou, tanto em texto quanto em uma imagem bonita.
#
# #### 🌟 **A Magia das Operações**
#
# Ao aprender sobre operações no Qiskit, estamos descobrindo como usar superpoderes para transformar e entender o mundo quântico. Cada operação é como um feitiço que nos ajuda a ver o universo de uma maneira nova e emocionante!
#
# E o mais divertido é que estamos fazendo tudo isso como se estivéssemos em uma história de aventuras, onde cada feitiço nos leva a descobertas incríveis! 🧙‍♂️✨🌌

# %%
from qiskit.quantum_info import Operator, Statevector
from numpy import sqrt

X = Operator([[0, 1], [1, 0]])
Y = Operator([[0, -1.0j], [1.0j, 0]])
Z = Operator([[1, 0], [0, -1]])
H = Operator([[1 / sqrt(2), 1 / sqrt(2)], [1 / sqrt(2), -1 / sqrt(2)]])
S = Operator([[1, 0], [0, 1.0j]])
T = Operator([[1, 0], [0, (1 + 1.0j) / sqrt(2)]])

# %%
v = Statevector([1, 0])

# %%
v = v.evolve(H)
v = v.evolve(T)
v = v.evolve(H)
v = v.evolve(T)
v = v.evolve(Z)

# %%
v.draw("text")

# %%
v.draw("latex")

# %% [markdown]
# ---
#
#
# Olhando para o futuro em direção aos circuitos quânticos
# Os circuitos quânticos não serão formalmente introduzidos até a Lição 3, mas podemos, no entanto, experimentar compor operações unitárias de qubit usando a classe QuantumCircuit do Qiskit. Em particular, podemos definir um circuito quântico (que neste caso será simplesmente uma sequência de operações unitárias realizadas em um único qubit) da seguinte forma.

# %%
from qiskit import QuantumCircuit

circuit = QuantumCircuit(1)

circuit.h(0)
circuit.t(0)
circuit.h(0)
circuit.t(0)
circuit.z(0)

circuit.draw()

# %% [markdown]
# ![Untitled (11).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# >` Vamos embarcar em uma nova aventura no mundo dos circuitos quânticos com Qiskit, de uma maneira bem fácil e divertida!`
#
#
# ---
#
#
#
# ## 🚀 **Introdução aos Circuitos Quânticos**
#
# #### **O que são Circuitos Quânticos?**
# Pense nos circuitos quânticos como mapas de aventura para nossos personagens quânticos (os qubits). Esses mapas nos mostram por quais feitiços (operações) os qubits passam durante a aventura.
#
# #### **Criando um Circuito Quântico com QuantumCircuit**
# Vamos criar um circuito para um único qubit. É como desenhar um caminho para ele seguir.
#
# 1. **Começando com QuantumCircuit**:
#    Primeiro, precisamos das ferramentas certas para desenhar nosso mapa de aventura. Usamos `QuantumCircuit` do Qiskit para isso.
#
#    ```python
#    from qiskit import QuantumCircuit
#
#    # Criando um circuito para 1 qubit
#    circuit = QuantumCircuit(1)
#    ```
#
# 2. **Adicionando Feitiços ao Circuito**:
#    Agora, vamos adicionar alguns feitiços ao nosso circuito. Cada feitiço é um passo na aventura do qubit.
#
#    - **H**: Este é um feitiço que mistura as coisas.
#    - **T**: Um feitiço que faz uma mudança menor, mas importante.
#    - **Z**: Este feitiço muda a direção de algo.
#
#    Vamos adicionar esses feitiços ao nosso circuito:
#
#    ```python
#    circuit.h(0)
#    circuit.t(0)
#    circuit.h(0)
#    circuit.t(0)
#    circuit.z(0)
#    ```
#
#    Cada `circuit.NOME_DO_FEITIÇO(0)` é como dizer ao qubit para passar por esse feitiço.
#
# #### **Desenhando o Circuito**
#
# 1. **Visualizando o Circuito**:
#    Agora, vamos ver como nosso mapa de aventura (o circuito) ficou.
#
#    ```python
#    circuit.draw()
#    ```
#
#    Isso vai mostrar uma imagem do circuito, com cada feitiço sendo um passo no caminho do qubit.
#
# #### 🌌 **O Mundo dos Circuitos Quânticos**
#
# Explorar os circuitos quânticos é como criar uma história de aventuras para os qubits. Cada operação no circuito é um capítulo dessa história, e ao final, depois de passar por todos os feitiços, o qubit acaba em um lugar totalmente novo e interessante!
#
# E o mais incrível é que, enquanto aprendemos sobre circuitos quânticos, estamos nos tornando pequenos exploradores no vasto universo da computação quântica! 🎩✨👩‍🚀🌌

# %%
from qiskit import QuantumCircuit

# Criando um circuito para 1 qubit
circuit = QuantumCircuit(1)

# %%
circuit.h(0)
circuit.t(0)
circuit.h(0)
circuit.t(0)
circuit.z(0)

# %%
circuit.draw()

# %% [markdown]
# As operações são aplicadas sequencialmente, começando à esquerda e terminando à direita na figura. Vamos primeiro inicializar um vetor de estado quântico inicial e, em seguida, evoluir esse estado de acordo com a sequência de operações.

# %%
ket0 = Statevector([1, 0])
v = ket0.evolve(circuit)
v.draw("text")

# %% [markdown]
# ---
#
#
# Finalmente, vamos simular o resultado da execução deste experimento (ou seja, preparar o estado ∣0⟩,\vert 0\rangle,∣0⟩, aplicando a sequência de operações representada pelo circuito, e medindo) 4000 vezes.

# %%
statistics = v.sample_counts(4000)
plot_histogram(statistics)

# %% [markdown]
# ![Untitled (10).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# > `Claro, vamos explorar como simular um experimento com um circuito quântico no Qiskit, de uma forma bem simples e divertida!`
#
#
#
# ---
#
#
#
# ## 🎢 **Simulando um Experimento Quântico**
#
# #### **Preparando a Aventura**
# Imagine que estamos se preparando para uma grande aventura no mundo quântico. Nosso personagem principal é o qubit, e ele começa no estado `|0⟩` (pense nele como um herói no começo de sua jornada).
#
# #### **Criando o Circuito da Aventura**
# Nós já criamos um circuito quântico especial para o nosso qubit com várias operações mágicas (feitiços como H, T e Z). Agora, queremos ver o que acontece com o nosso herói qubit depois que ele passa por todas essas aventuras.
#
# #### **Simulando o Experimento**
# Para simular nossa aventura, vamos fazer algo chamado medição muitas vezes. Isso é como verificar muitas vezes para ver em que estado nosso qubit herói acabou após a aventura.
#
# 1. **Fazendo a Medição**:
#    Vamos fingir que estamos medindo o estado final do nosso qubit 4000 vezes. Isso é como assistir ao final da aventura 4000 vezes para ver o que mais comumente acontece com o herói.
#
#    ```python
#    statistics = v.sample_counts(4000)
#    ```
#
# 2. **Visualizando os Resultados**:
#    Depois de fazer todas essas medições, vamos usar algo chamado `plot_histogram` para ver os resultados. Isso é como um gráfico que nos mostra quantas vezes nosso herói qubit acabou em cada estado possível após a aventura.
#
#    ```python
#    from qiskit.visualization import plot_histogram
#    plot_histogram(statistics)
#    ```
#
#    Isso vai criar um belo gráfico que nos mostra se o nosso qubit herói acabou mais vezes no estado `|0⟩` ou no estado `|1⟩` depois de todas as aventuras.
#
# #### 🌟 **A Magia da Simulação Quântica**
#
# Simular este experimento é como assistir a um filme sobre o nosso herói qubit várias vezes e anotar os diferentes finais. Às vezes, ele pode terminar de uma maneira, às vezes de outra. Isso nos ajuda a entender as probabilidades no mundo quântico, que é cheio de surpresas e finais emocionantes!
#
# E o mais incrível é que estamos aprendendo sobre física quântica e computação de uma maneira super divertida, como se estivéssemos em uma grande aventura científica! 🚀✨👩‍🔬🌌

# %%
statistics = v.sample_counts(4000)

# %%
from qiskit.visualization import plot_histogram
plot_histogram(statistics)

# %% [markdown]
# ![Untitled (13).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# > `Claro! Vamos recapitular nossa aventura de aprendizado passo a passo, explicando cada etapa de maneira simples e acessível:`
#
#
#
# ---
# # **Recapitular nossa aventura de aprendizado**
#
#
# ### **1. Introdução ao Qiskit e Conceitos Básicos**
# Começamos nossa jornada explorando o Qiskit, uma ferramenta usada para programar computadores quânticos. Imagine o Qiskit como uma caixa de ferramentas mágica que nos ajuda a entender e criar coisas para o mundo quântico.
#
# ### 2. **Vetores e Matrizes em Python**
# Entramos no mundo dos vetores e matrizes usando Python. Pense em vetores como setas que apontam para diferentes lugares, e matrizes como tabelas cheias de números. Aprendemos a fazer cálculos simples com eles, usando uma parte do Python chamada NumPy.
#
# ### 3. **Usando a Classe Statevector**
# Descobrimos a classe `Statevector` no Qiskit, que é como uma varinha mágica para criar e mudar estados quânticos. Estados quânticos são como personagens em um jogo que podem estar em diferentes posições ou estados.
#
# ### 4. **Desenhando e Verificando Estados Quânticos**
# Aprendemos como desenhar esses estados quânticos de maneiras diferentes e como verificar se eles são válidos usando `is_valid`. Isso é como ter um detector que nos diz se o nosso personagem quântico está pronto para a aventura.
#
# ### 5. **Simulando Medições Quânticas**
# Exploramos como simular medições no mundo quântico. Medições são como descobrir segredos sobre os nossos personagens quânticos, e os resultados podem ser surpreendentes e diferentes cada vez.
#
# ### 6. **Experimentando com Diferentes Resultados**
# Vimos que, ao medir várias vezes, podemos obter resultados diferentes. É como se cada medição fosse uma nova chance para o personagem quântico mostrar algo diferente sobre si mesmo.
#
# ### 7. **Introdução aos Circuitos Quânticos**
# Avançamos para o mundo dos circuitos quânticos. Circuitos são como mapas de aventura que guiam os qubits (nossos heróis quânticos) através de várias operações ou feitiços.
#
# ### 8. **Criando e Operando Circuitos Quânticos**
# Criamos um circuito quântico e adicionamos operações como H, T e Z. Cada operação é como um capítulo na história de aventura do nosso qubit.
#
# ### 9. **Simulando um Experimento Completo**
# Finalmente, simulamos um experimento completo, medindo o resultado de um circuito quântico 4000 vezes. Isso nos ajudou a entender como os resultados quânticos são baseados em probabilidades e como eles podem variar.
#
# Em cada etapa, usamos linguagem e analogias simples para tornar a aprendizagem divertida e acessível, transformando conceitos complexos em uma aventura emocionante no mundo da computação quântica! 🌟🔍✨🚀

# %% [markdown]
# ---
#
#
# > `Durante nossa jornada de aprendizado no Qiskit, abordamos vários conceitos matemáticos importantes que são fundamentais na computação quântica. Vou resumir os principais estudos matemáticos apresentados:`
#
#
#
#
# ---
#
#
# # **Conceitos matemáticos importantes que são fundamentais na computação quântica aqui estudada:**
#
#
# ### 1. **Vetores e Matrizes**
#    - **Conceito de Vetores**: Entendemos vetores como representações de estados quânticos, ilustrando-os como setas em um espaço.
#    - **Manipulação de Matrizes**: Aprendemos sobre matrizes e como elas são usadas em operações quânticas, incluindo a representação de operadores quânticos.
#
# ### 2. **Operações com Vetores e Matrizes**
#    - **Cálculos com Vetores**: Realizamos operações básicas com vetores, como adição e divisão por escalares.
#    - **Multiplicação de Matrizes**: Exploramos como multiplicar matrizes e vetores, uma operação crucial na transformação de estados quânticos.
#
# ### 3. **Funções Matemáticas Específicas**
#    - **Uso da Raiz Quadrada**: Utilizamos a função de raiz quadrada (sqrt) do NumPy para normalizar vetores e em operações com operadores quânticos.
#
# ### 4. **Probabilidade e Estatística**
#    - **Conceitos de Probabilidade**: Abordamos como a medição de estados quânticos é uma ação probabilística, fundamental na mecânica quântica.
#    - **Análise de Resultados**: Usamos estatísticas para interpretar os resultados de múltiplas medições quânticas.
#
# ### 5. **Representações Gráficas**
#    - **Histogramas**: Aprendemos a usar histogramas para visualizar a distribuição de resultados de medições quânticas, uma ferramenta importante para entender a natureza probabilística dos qubits.
#
# ### 6. **Fase Global e Números Complexos**
#    - **Introdução a Números Complexos**: Toquei brevemente no conceito de números complexos, essenciais na descrição de estados quânticos.
#
# ### 7. **Conceitos de Física Quântica**
#    - **Superposição e Entrelaçamento**: Enquanto não aprofundamos matematicamente nestes conceitos, eles foram mencionados como parte do entendimento geral da computação quântica.
#
# Estes estudos matemáticos são a espinha dorsal da computação quântica e essenciais para entender como o Qiskit opera e como os computadores quânticos funcionam. Eles fornecem as ferramentas necessárias para explorar mais a fundo este fascinante campo da ciência.

# %% [markdown]
# # **BASES MATEMÁTICAS ABORDADA NESSE ESTUDO**

# %% [markdown]
# ### 1. Vetores e Matrizes
#
# Para entender vetores e matrizes de uma maneira que seja fácil para alguém de 10 anos, vamos usar algumas analogias e exemplos simples.
#
# #### Vetores
# Imagine um vetor como uma seta em um espaço. Essa seta pode apontar em diferentes direções e ter diferentes comprimentos. No mundo da computação quântica, usamos vetores para representar o estado de algo, como um qubit.
#
# **Exemplo de um Vetor**:
# Um vetor simples pode ser [3, 4]. Isso é como uma seta que se move 3 passos para a direita e 4 passos para cima. Se você desenhar isso num papel quadriculado, parece uma seta indo do canto inferior esquerdo para um ponto mais acima à direita.
#
# #### Matrizes
# Uma matriz é como uma grande caixa cheia de números, organizados em linhas e colunas. Elas são usadas para fazer operações nos vetores, como mudá-los de posição ou girá-los.
#
# **Exemplo de uma Matriz**:
# Uma matriz pode parecer algo assim:
#
# ```
# [2, 0]
# [0, 2]
# ```
#
# Esta matriz tem 2 linhas e 2 colunas. Se você aplicar esta matriz ao vetor [3, 4], ela multiplicará cada parte do vetor pelos números correspondentes da matriz. Vamos ver como isso funciona:
#
# Multiplicação de Matriz por Vetor:
# ```
# [2, 0]   [3]   [2 * 3 + 0 * 4]   [6]
# [0, 2] * [4] = [0 * 3 + 2 * 4] = [8]
# ```
#
# O que fizemos foi pegar o primeiro número do vetor (3), multiplicar pelo primeiro número da primeira linha da matriz (2), e depois somar isso ao segundo número do vetor (4) multiplicado pelo segundo número da primeira linha da matriz (0). Isso nos dá 6. Repetimos o processo para a segunda linha da matriz, que nos dá 8. Então, o resultado é o vetor [6, 8].
#
# Esses conceitos são a base para entender como operações e transformações são realizadas em computação quântica. Vetores nos ajudam a entender onde estamos, e matrizes nos ajudam a entender como podemos mudar para onde queremos ir.

# %% [markdown]
# ### 2. Operações com Vetores e Matrizes
#
# Vamos explorar como realizar operações básicas com vetores e matrizes, mantendo a explicação acessível e técnica ao mesmo tempo.
#
# #### Operações com Vetores
# Os vetores, como já mencionamos, são como setas ou listas de números que representam uma direção e magnitude. Vamos ver algumas operações comuns com vetores.
#
# **Exemplo de Vetor**:
# Vamos considerar um vetor simples: `v = [3, 4]`.
#
# 1. **Adição de Vetores**:
#    Imagine que você tem dois vetores, `v = [3, 4]` e `u = [1, 2]`. Se quisermos adicionar esses vetores, simplesmente somamos seus componentes correspondentes.
#
#    ```
#    v + u = [3 + 1, 4 + 2] = [4, 6]
#    ```
#
#    É como se você andasse 3 passos para frente e depois mais 1 passo, totalizando 4 passos. O mesmo se aplica à outra direção (vertical neste caso).
#
# 2. **Multiplicação por Escalar**:
#    Multiplicar um vetor por um escalar (um número simples) é como esticar ou encolher a seta. Se multiplicarmos `v = [3, 4]` por 2, estamos dobrando seu tamanho.
#
#    ```
#    2 * v = [2 * 3, 2 * 4] = [6, 8]
#    ```
#
#    Isso significa que cada parte do vetor foi dobrada.
#
# #### Operações com Matrizes
# As matrizes, como grandes caixas de números, também podem ser manipuladas. Vamos ver a multiplicação de matrizes, que é um pouco mais complexa.
#
# **Exemplo de Matriz**:
# Considere uma matriz simples: `M = [[2, 0], [0, 2]]`.
#
# 1. **Multiplicação de Matriz por Vetor**:
#    Para multiplicar a matriz `M` pelo vetor `v`, seguimos um método passo a passo:
#
#    ```
#    M * v = [[2, 0], [0, 2]] * [3, 4]
#
#          = [2 * 3 + 0 * 4, 0 * 3 + 2 * 4]
#          = [6, 8]
#    ```
#
#    Isso é como aplicar uma transformação ao vetor, mudando sua direção e magnitude com base nos números da matriz.
#
# 2. **Multiplicação de Matriz por Matriz**:
#    Quando multiplicamos duas matrizes, estamos combinando suas transformações. O processo é um pouco mais complicado, mas segue uma lógica similar à multiplicação matriz-vetor.
#
#    Se tivermos outra matriz `N = [[1, 1], [1, -1]]` e quisermos multiplicar `M * N`, fazemos isso multiplicando cada linha de `M` por cada coluna de `N` e somando os resultados.
#
#    ```
#    M * N = [[2, 0], [0, 2]] * [[1, 1], [1, -1]]
#
#          = [[2*1 + 0*1, 2*1 + 0*-1],
#             [0*1 + 2*1, 0*1 + 2*-1]]
#          = [[2, 2], [2, -2]]
#    ```
#
# Estas operações são a base para entender como manipulamos estados e realizamos cálculos em computação quântica. Ao aprender sobre vetores e matrizes, estamos construindo a fundação necessária para explorar o fascinante mundo da mecânica quântica e da programação quântica.

# %% [markdown]
# ### 3. Funções Matemáticas Específicas
#
# Vamos explorar algumas funções matemáticas específicas que são frequentemente usadas na computação quântica, mantendo a explicação técnica, mas acessível.
#
# #### Uso da Raiz Quadrada (sqrt)
# A função de raiz quadrada é um conceito matemático que pergunta: "Qual número, multiplicado por si mesmo, dá o número original?". Na computação quântica, ela é frequentemente usada para normalizar vetores ou em operações com operadores quânticos.
#
# **Exemplo com Vetores**:
# Se tivermos um vetor `v = [3, 4]`, a magnitude (ou comprimento) desse vetor é calculada usando a raiz quadrada. A magnitude é importante porque, em computação quântica, os vetores de estado (que representam o estado de um qubit) precisam ter uma magnitude de 1 para serem válidos.
#
# 1. **Calculando a Magnitude de um Vetor**:
#    A magnitude de `v = [3, 4]` é calculada como:
#
#    ```
#    magnitude = sqrt(3² + 4²)
#              = sqrt(9 + 16)
#              = sqrt(25)
#              = 5
#    ```
#
#    Portanto, o vetor `v` tem um comprimento ou magnitude de 5.
#
# 2. **Normalizando um Vetor**:
#    Para normalizar o vetor (fazê-lo ter magnitude 1), dividimos cada componente do vetor pela sua magnitude.
#
#    ```
#    v_normalizado = [3/5, 4/5]
#                   = [0.6, 0.8]
#    ```
#
#    Agora, `v_normalizado` tem uma magnitude de 1, que é um requisito para vetores de estado em computação quântica.
#
# #### Aplicação em Operadores Quânticos
# Na computação quântica, a raiz quadrada também é usada na definição de certos operadores quânticos, como o operador Hadamard (H). O operador Hadamard é fundamental na criação de superposições de estados em qubits.
#
# 1. **Operador Hadamard (H)**:
#    O operador Hadamard é definido como:
#
#    ```
#    H = 1/sqrt(2) * [[1,  1],
#                     [1, -1]]
#    ```
#
#    Este operador, quando aplicado a um qubit, cria uma superposição, que é um conceito central na mecânica quântica e na computação quântica.
#
# Essas funções matemáticas, como a raiz quadrada, são ferramentas essenciais para trabalhar com conceitos quânticos. Elas nos ajudam a entender como transformar e manipular estados quânticos de maneira precisa e significativa.

# %% [markdown]
# ### 4. Probabilidade e Estatística na Computação Quântica
#
# Vamos explorar como a probabilidade e a estatística são aplicadas na computação quântica, mantendo uma linguagem simples e acessível.
#
# #### Conceitos de Probabilidade
# Na computação quântica, quando medimos um qubit, o resultado é probabilístico. Isso significa que, ao contrário de um computador clássico que nos dá uma resposta definitiva (0 ou 1), um qubit pode nos dar uma resposta que tem uma certa probabilidade de ser 0 ou 1.
#
# **Exemplo de Probabilidade com um Qubit**:
# Imagine que temos um qubit em um estado de superposição, onde as chances de medir 0 ou 1 são iguais. Podemos representar isso como `|ψ⟩ = 1/sqrt(2) * |0⟩ + 1/sqrt(2) * |1⟩`. Quando medimos este qubit, há 50% de chance de obter 0 e 50% de chance de obter 1.
#
# #### Análise de Resultados
# Na prática, não medimos um qubit apenas uma vez. Medimos muitas vezes para entender melhor o estado do qubit. Isso é onde a estatística entra.
#
# 1. **Medindo Múltiplas Vezes**:
#    Se medirmos nosso qubit em superposição 100 vezes, esperamos encontrar cerca de 50 vezes o resultado 0 e 50 vezes o resultado 1. Claro, devido à natureza probabilística, os números exatos podem variar um pouco.
#
# 2. **Histogramas**:
#    Usamos histogramas para visualizar os resultados das medições. Um histograma é um tipo de gráfico que mostra quantas vezes cada resultado ocorre. Se tivermos um histograma dos resultados de nossas 100 medições, veríamos duas barras (uma para 0 e outra para 1) de altura aproximadamente igual.
#
# #### Exemplo de Simulação de Medição
# Quando usamos um simulador quântico como o Qiskit para medir um qubit 4000 vezes, o histograma dos resultados nos dará uma boa ideia de quão prováveis são os diferentes resultados. Se o qubit estiver em um estado onde 0 é mais provável do que 1, veríamos uma barra maior para 0 no histograma.
#
# Estas ferramentas e conceitos nos ajudam a entender melhor o comportamento dos qubits e a natureza probabilística da mecânica quântica. Ao aprender sobre probabilidade e estatística na computação quântica, estamos ganhando insights valiosos sobre como os computadores quânticos funcionam e como podemos utilizá-los para realizar cálculos complexos.

# %% [markdown]
# ### 5. Introdução aos Circuitos Quânticos
#
# Agora vamos explorar o conceito de circuitos quânticos de uma forma acessível e com detalhes técnicos adequados.
#
# #### O que são Circuitos Quânticos?
# Pense em um circuito quântico como um mapa de aventuras para qubits (as unidades básicas da computação quântica). Assim como em um videogame, onde o personagem passa por diferentes fases e desafios, os qubits passam por várias "operações" ou "portas" em um circuito quântico. Estas operações mudam o estado dos qubits de maneiras específicas.
#
# #### Construindo um Circuito Quântico
# Para construir um circuito quântico no Qiskit, usamos a classe `QuantumCircuit`. Vamos criar um circuito simples:
#
# 1. **Criando o Circuito**:
#    ```python
#    from qiskit import QuantumCircuit
#
#    # Criando um circuito para um qubit
#    circuit = QuantumCircuit(1)
#    ```
#
#    Aqui, `QuantumCircuit(1)` cria um circuito para um único qubit.
#
# 2. **Adicionando Operações ao Circuito**:
#    Agora, adicionamos algumas operações básicas, como Hadamard (H), T e Z, ao qubit.
#
#    - **Hadamard (H)**: Cria uma superposição de estados.
#    - **T**: Uma operação de rotação mais sutil.
#    - **Z**: Muda a fase do qubit.
#
#    ```python
#    circuit.h(0)  # Aplica Hadamard no qubit 0
#    circuit.t(0)  # Aplica T no qubit 0
#    circuit.h(0)  # Aplica Hadamard novamente
#    circuit.t(0)  # Aplica T novamente
#    circuit.z(0)  # Aplica Z no qubit 0
#    ```
#
#    Cada `circuit.NOME_DO_FEITIÇO(0)` adiciona uma operação ao qubit no circuito.
#
# #### Visualizando o Circuito
# Para ver como o circuito ficou, usamos o método `draw()`:
#
# ```python
# circuit.draw()
# ```
#
# Este comando mostra uma representação gráfica do circuito, onde cada operação é representada por um símbolo em uma linha que representa o qubit.
#
# #### Por que Circuitos Quânticos são Importantes?
# Os circuitos quânticos são fundamentais porque nos permitem planejar e visualizar as operações que queremos realizar nos qubits. Eles são a base para algoritmos quânticos e para realizar cálculos complexos em computadores quânticos. Ao entender os circuitos quânticos, começamos a ver como podemos usar os princípios quânticos para resolver problemas de maneiras que os computadores clássicos não conseguem.

# %% [markdown]
# ### 6. Operações e Transformações Quânticas
#
# Vamos mergulhar no mundo fascinante das operações e transformações quânticas, explicando de forma simples e técnica.
#
# #### Operações Quânticas Básicas
# Operações quânticas, também conhecidas como portas quânticas, são como comandos ou instruções que mudam o estado de um qubit de maneiras específicas. Cada operação tem uma função única e contribui para a criação de um algoritmo quântico.
#
# 1. **Operador Hadamard (H)**:
#    - **Função**: Cria uma superposição de estados. Se aplicado a um qubit no estado |0⟩, o H coloca o qubit em um estado de igual probabilidade de ser medido como |0⟩ ou |1⟩.
#    - **Matriz**:
#      ```
#      H = 1/sqrt(2) * [[1,  1],
#                       [1, -1]]
#      ```
#    - **Efeito**: Transforma o estado |0⟩ em (|0⟩ + |1⟩)/sqrt(2).
#
# 2. **Operador T**:
#    - **Função**: Realiza uma rotação mais sutil no estado do qubit.
#    - **Matriz**:
#      ```
#      T = [[1, 0],
#           [0, e^(iπ/4)]]
#      ```
#    - **Efeito**: Adiciona uma fase complexa ao estado |1⟩ do qubit.
#
# 3. **Operador Z**:
#    - **Função**: Muda a fase do qubit.
#    - **Matriz**:
#      ```
#      Z = [[1,  0],
#           [0, -1]]
#      ```
#    - **Efeito**: Altera o sinal do estado |1⟩.
#
# #### Transformações Quânticas
# Uma transformação quântica ocorre quando aplicamos uma ou mais operações a um qubit. Cada operação altera o estado do qubit de uma maneira específica, levando a um novo estado quântico.
#
# #### Exemplo de Transformação
# Vamos considerar um qubit inicialmente no estado |0⟩ e aplicar uma série de operações:
#
# 1. **Aplicando Hadamard (H)**:
#    - Transforma |0⟩ em (|0⟩ + |1⟩)/sqrt(2), criando uma superposição.
#
# 2. **Aplicando T**:
#    - Adiciona uma fase ao estado |1⟩ da superposição.
#
# 3. **Aplicando Z**:
#    - Inverte o sinal do estado |1⟩ na superposição.
#
# Cada operação muda o estado do qubit passo a passo. O estado final do qubit após essas operações é uma combinação complexa dos estados básicos |0⟩ e |1⟩, que representa a essência da computação quântica: a capacidade de existir em múltiplos estados ao mesmo tempo (superposição) e a utilização de fases complexas.
#
# #### Por que Isso é Importante?
# Entender operações e transformações quânticas é crucial porque elas são os blocos de construção dos algoritmos quânticos. Ao aprender sobre essas operações, começamos a compreender como os computadores quânticos realizam cálculos e como podem resolver problemas de maneiras que vão além das capacidades dos computadores clássicos.

# %% [markdown]
# ### 7. Simulação de Experimentos Quânticos
#
# Vamos mergulhar na simulação de experimentos quânticos, explicando de forma acessível e mantendo o rigor técnico.
#
# #### O Que é Simulação de Experimentos Quânticos?
# Na computação quântica, muitas vezes queremos saber como um qubit, ou um grupo de qubits, se comportará quando passar por várias operações quânticas. A simulação de experimentos quânticos envolve a criação de um modelo desses processos em um computador, permitindo-nos ver os resultados sem a necessidade de um computador quântico real.
#
# #### Etapas da Simulação
# 1. **Preparando o Estado Inicial**:
#    - Começamos definindo o estado inicial do nosso qubit, geralmente o estado |0⟩.
#
# 2. **Aplicando Operações Quânticas**:
#    - Realizamos uma série de operações (como Hadamard, T, Z) no qubit, alterando seu estado.
#
# 3. **Medindo o Resultado**:
#    - Ao final das operações, medimos o estado do qubit. Como a medição em computação quântica é probabilística, não obtemos sempre o mesmo resultado.
#
# 4. **Repetindo a Medição**:
#    - Para obter uma boa ideia de como o qubit se comporta, repetimos a medição muitas vezes. Cada repetição é chamada de "ensaio" ou "trial".
#
# #### Exemplo de Simulação
# Imaginemos um experimento onde aplicamos um Hadamard a um qubit no estado |0⟩, seguido por uma operação T. Depois disso, medimos o qubit. Se repetirmos esse processo muitas vezes, veremos uma distribuição de probabilidades para o qubit ser medido como |0⟩ ou |1⟩.
#
# 1. **Simulação no Qiskit**:
#    - No Qiskit, podemos usar simuladores para repetir o experimento milhares de vezes e coletar estatísticas.
#    - Essas estatísticas são geralmente apresentadas em um histograma, mostrando a frequência relativa dos resultados |0⟩ e |1⟩.
#
# #### Por que a Simulação é Importante?
# Simular experimentos quânticos é crucial por várias razões:
# - **Testar e Desenvolver Algoritmos**: Permite-nos testar e refinar algoritmos quânticos sem a necessidade de um computador quântico real.
# - **Entender Comportamentos Quânticos**: Ajuda a compreender como operações quânticas afetam os qubits e a explorar a natureza probabilística da medição quântica.
# - **Educação e Pesquisa**: É uma ferramenta valiosa para ensinar conceitos de computação quântica e para a pesquisa em algoritmos quânticos.
#
# Ao simular experimentos quânticos, estamos abrindo uma janela para o futuro da computação, explorando o potencial e as limitações da tecnologia quântica de uma maneira prática e acessível.
